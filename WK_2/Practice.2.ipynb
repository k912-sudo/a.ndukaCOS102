# %%
# Input from user
m = float(input("Put mass in KG: "))
c = 299792458
energy = m * c ** 2
print(f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# Put mass in KG:  7777
# The energy equivalent to 7777.0 kg of mass is 6.98961902503623e+20 joules.
