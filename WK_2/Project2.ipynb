# %%
import numpy as np

def get_roots(coefficients):
    """Calculates roots for any polynomial given its coefficients."""
    roots = np.roots(coefficients)
    return roots

def main():
    print("--- Equation Root Finder ---")
    print("1. Quadratic Equation (Ax² + Bx + C = 0)")
    print("2. Cubic Equation (Ax³ + Bx² + Cx + D = 0)")
    print("3. Quartic Equation (Ax⁴ + Bx³ + Cx² + Dx + E = 0)")
    
    choice = input("\nSelect the operation (1, 2, or 3): ")

    if choice == '1':
        print("\nEnter coefficients for Ax² + Bx + C = 0")
        a = float(input("A: "))
        b = float(input("B: "))
        c = float(input("C: "))
        coeffs = [a, b, c]
    
    elif choice == '2':
        print("\nEnter coefficients for Ax³ + Bx² + Cx + D = 0")
        a = float(input("A: "))
        b = float(input("B: "))
        c = float(input("C: "))
        d = float(input("D: "))
        coeffs = [a, b, c, d]

    elif choice == '3':
        print("\nEnter coefficients for Ax⁴ + Bx³ + Cx² + Dx + E = 0")
        a = float(input("A: "))
        b = float(input("B: "))
        c = float(input("C: "))
        d = float(input("D: "))
        e = float(input("E: "))
        coeffs = [a, b, c, d, e]
    
    else:
        print("Invalid selection.")
        return

    # Calculate and display roots
    roots = get_roots(coeffs)
    print("\nThe roots are:")
    for i, root in enumerate(roots, 1):
        # Formatting to show real numbers clearly and complex numbers if they exist
        print(f"Root {i}: {root}")

if __name__ == "__main__":
    main()
# Out:
# --- Equation Root Finder ---
# 1. Quadratic Equation (Ax² + Bx + C = 0)
# 2. Cubic Equation (Ax³ + Bx² + Cx + D = 0)
# 3. Quartic Equation (Ax⁴ + Bx³ + Cx² + Dx + E = 0)
