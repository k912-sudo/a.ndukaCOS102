# %%
game_1 = 2
game_2 = 4
print(bool(game_1 == game_2))
print(game_1 == game_2)
val = None
print(bool(val))
num = ()
print(bool(num))
age = True
print(bool(age))
# Out:
# False
# False
# False
# False
# True

# %%
grade = int(70)
gpa = int(4.9)
cgpa = int("4")
print(f"Grade = {grade}")
print(f"Gpa = {gpa}")
print(f"grade = {cgpa}")
# Out:
# Grade = 70
# Gpa = 4
# grade = 4

# %% [raw]
# grade = float(97)
# gpa = float(4.7)
# cgpa = float("5")
# print(f"Grade = {grade}")
# print(f"Gpa = {gpa}")
# print(f"grade = {cgpa}")
